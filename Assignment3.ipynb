# %%
#1. Write a python function to Capitalize all words in a list of strings
lis=["helo","hi","bye"]
r=list(map(lambda x:x.capitalize(),lis))
print(r)
# Out:
# ['Helo', 'Hi', 'Bye']

# %%
#2. Write a python function to Convert list of strings to their lengths
lis=["helo","hi","bye"]
r=list(map(lambda x:len(x),lis))
print(r)
# Out:
# [4, 2, 3]

# %%
#3. Write a python function to Filter out strings that are palindromes
lis=["helo","madam","hi","bye","oppo"]
r=list(filter(lambda x:x if x==x[::-1] else None,lis))
print(r)
# Out:
# ['madam', 'oppo']

# %%
#4. Write a python function to Concatenate all strings into one
from functools import reduce
lis=["helo","madam","hi","bye","oppo"]
r=reduce(lambda x,y:"".join(x)+"".join(y),lis)
print(r)
# Out:
# helomadamhibyeoppo

# %%
#5. Write a python function to Find the longest string in a list
lis=["helo","madam","hi","bye","oppo"]
r=reduce(lambda x,y:x if len(x)>len(y) else y,lis)
print(r)
# Out:
# madam

# %%
#6. Write a python function to Create a list of tuples (index, string) for strings starting with 'b'
lis=["helo","madam","hi","bye","oppo","ball"]
r=list(filter(lambda x:x[1].startswith('b'),enumerate(lis)))
print(r)
# Out:
# [(3, 'bye'), (5, 'ball')]

# %%
#7. Write a python function to Find index of the longest string
lis=["helo","madam","hi","bye","oppo"]
r=reduce(lambda x,y:x if len(x)>len(y) else y,lis)
print(lis.index(r))
# Out:
# 1

# %%
#8. Write a python function to Reverse each string in the list
lis=["helo","madam","hi","bye","oppo"]
r=list(map(lambda x:x[::-1],lis))
print(r)
# Out:
# ['oleh', 'madam', 'ih', 'eyb', 'oppo']

# %%
#9. Write a python function to Get ASCII values of characters in a string
a="Hello"
r=list(map(lambda x:ord(x),a))
print(r)
# Out:
# [72, 101, 108, 108, 111]

# %%
#10. Write a python function to Filter strings that start with a vowel
lis=["apple","mango","orange"]
r=list(filter(lambda x:x.startswith('a') or x.startswith('e') or x.startswith('i') or x.startswith('o') or x.startswith('u'),lis))
print(r)
# Out:
# ['apple', 'orange']
